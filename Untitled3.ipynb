# %%
import pandas as pd

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
submission_example = pd.read_csv('gender_submission.csv')

print(train_data.head())
print(test_data.head())
print(submission_example.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
# prompt: perform eda

# Basic information about the training data
print(train_data.info())
print(train_data.describe())

# Check for missing values
print(train_data.isnull().sum())

# Explore categorical features
for column in train_data.select_dtypes(include=['object']):
  print(f"\nColumn: {column}")
  print(train_data[column].value_counts())

# Explore numerical features (e.g., histograms, boxplots)
import matplotlib.pyplot as plt
import seaborn as sns

for column in train_data.select_dtypes(include=['number']):
  plt.figure()
  sns.histplot(train_data[column])
  plt.title(f"Distribution of {column}")
  plt.show()

# Correlation matrix for numerical features
# Select only numerical features for correlation calculation
numerical_features = train_data.select_dtypes(include=['number'])
correlation_matrix = numerical_features.corr()  # Calculate correlation on numerical features only

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()



# ... and so on ...
# You can further explore relationships, outliers, and other aspects
# based on your specific needs and the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
# prompt: do data cleaning

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
submission_example = pd.read_csv('gender_submission.csv')


# Handling missing values
# Fill missing Age values with the median age
train_data['Age'].fillna(train_data['Age'].median(), inplace=True)
test_data['Age'].fillna(test_data['Age'].median(), inplace=True)

# Fill missing Embarked values with the most frequent value (mode)
train_data['Embarked'].fillna(train_data['Embarked'].mode()[0], inplace=True)

# Fill missing Fare value in test data with the median fare
test_data['Fare'].fillna(test_data['Fare'].median(), inplace=True)

# Drop Cabin column (high number of missing values)
train_data.drop('Cabin', axis=1, inplace=True)
test_data.drop('Cabin', axis=1, inplace=True)

# Convert categorical features to numerical using one-hot encoding
train_data = pd.get_dummies(train_data, columns=['Sex', 'Embarked'])
test_data = pd.get_dummies(test_data, columns=['Sex', 'Embarked'])

# Feature engineering (e.g., create a new feature 'FamilySize')
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch'] + 1
test_data['FamilySize'] = test_data['SibSp'] + test_data['Parch'] + 1

# You can further explore and engineer features based on your analysis

# Check for any remaining missing values
print(train_data.isnull().sum())
print(test_data.isnull().sum())

# ... (rest of your code for analysis and modeling) ...
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# FamilySize     0
# dtype: int64
# PassengerId    0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# FamilySize     0
# dtype: int64
# <ipython-input-11-58d6caa9d045>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# prompt: do pre-processing

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
submission_example = pd.read_csv('gender_submission.csv')


# --- Data Preprocessing ---

# 1. Handle Missing Values
# Fill missing Age values with the median age
train_data['Age'].fillna(train_data['Age'].median(), inplace=True)
test_data['Age'].fillna(test_data['Age'].median(), inplace=True)

# Fill missing Embarked values with the most frequent value (mode)
train_data['Embarked'].fillna(train_data['Embarked'].mode()[0], inplace=True)

# Fill missing Fare value in test data with the median fare
test_data['Fare'].fillna(test_data['Fare'].median(), inplace=True)

# 2. Drop Unnecessary Features
# Drop Cabin column (high number of missing values)
train_data.drop('Cabin', axis=1, inplace=True)
test_data.drop('Cabin', axis=1, inplace=True)

# 3. Convert Categorical Features to Numerical (One-Hot Encoding)
train_data = pd.get_dummies(train_data, columns=['Sex', 'Embarked'])
test_data = pd.get_dummies(test_data, columns=['Sex', 'Embarked'])

# 4. Feature Engineering
# Create a new feature 'FamilySize'
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch'] + 1
test_data['FamilySize'] = test_data['SibSp'] + test_data['Parch'] + 1

# 5. Verify Missing Values (Optional)
print(train_data.isnull().sum())
print(test_data.isnull().sum())

# --- Continue with Data Analysis and Modeling ---
# ... (rest of your code for analysis and modeling) ...
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# FamilySize     0
# dtype: int64
# PassengerId    0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# FamilySize     0
# dtype: int64
# <ipython-input-15-44e7bffda86d>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

features = data[['Pclass', 'Age', 'Fare']]
features = features.dropna()  # Ensure no missing values for PCA
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3ef5344603a7> in <cell line: 4>()
#       2 from sklearn.preprocessing import StandardScaler
#       3
# ----> 4 features = data[['Pclass', 'Age', 'Fare']]
#       5 features = features.dropna()  # Ensure no missing values for PCA
#       6 scaler = StandardScaler()
#
# NameError: name 'data' is not defined

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming you want to apply PCA to the training data:
data = train_data  # Assign train_data to the variable 'data'

features = data[['Pclass', 'Age', 'Fare']]
features = features.dropna()  # Ensure no missing values for PCA
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(principal_components, data['Survived'], test_size=0.2, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79       105
#            1       0.79      0.42      0.55        74
#
#     accuracy                           0.72       179
#    macro avg       0.74      0.67      0.67       179
# weighted avg       0.74      0.72      0.69       179

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Split data
X_train, X_test, y_train, y_test = train_test_split(data_pca, data_cleaned['target'], test_size=0.2, random_state=42)

# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6cb26cf5326f> in <cell line: 5>()
#       3
#       4 # Split data
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(data_pca, data_cleaned['target'], test_size=0.2, random_state=42)
#       6
#       7 # Train model
#
# NameError: name 'data_pca' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


# Assuming 'data' contains your preprocessed data (e.g., train_data)
features = data[['Pclass', 'Age', 'Fare']]
features = features.dropna()  # Ensure no missing values for PCA
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

pca = PCA(n_components=2)
data_pca = pca.fit_transform(scaled_features) # Perform PCA and store results in 'data_pca'

# Split data
X_train, X_test, y_train, y_test = train_test_split(data_pca, data['Survived'], test_size=0.2, random_state=42)

# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

# Predict
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.6703910614525139

# %%
from sklearn.metrics import classification_report

# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73       105
#            1       0.62      0.54      0.58        74
#
#     accuracy                           0.67       179
#    macro avg       0.66      0.65      0.65       179
# weighted avg       0.67      0.67      0.67       179

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(X_train, y_train)
y_pred_knn = model_knn.predict(X_test)
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.82      0.74       105
#            1       0.64      0.46      0.54        74
#
#     accuracy                           0.67       179
#    macro avg       0.66      0.64      0.64       179
# weighted avg       0.67      0.67      0.66       179

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
y_pred_lr = model_lr.predict(X_test)
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79       105
#            1       0.79      0.42      0.55        74
#
#     accuracy                           0.72       179
#    macro avg       0.74      0.67      0.67       179
# weighted avg       0.74      0.72      0.69       179

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
y_pred_dt = model_dt.predict(X_test)
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72       105
#            1       0.60      0.50      0.54        74
#
#     accuracy                           0.65       179
#    macro avg       0.64      0.63      0.63       179
# weighted avg       0.65      0.65      0.65       179

# %%
# prompt: make decision tree and visulize it as well

from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Assuming X_train and y_train are your training data
# ... (Your code for data preprocessing and splitting) ...

# Train a Decision Tree model
model_dt = DecisionTreeClassifier(max_depth=3)  # You can adjust max_depth
model_dt.fit(X_train, y_train)

# Visualize the Decision Tree
plt.figure(figsize=(15, 10))
plot_tree(model_dt, feature_names=features.columns, class_names=['Not Survived', 'Survived'], filled=True)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

model_nb = GaussianNB()
model_nb.fit(X_train, y_train)
y_pred_nb = model_nb.predict(X_test)
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.87      0.75       105
#            1       0.66      0.36      0.47        74
#
#     accuracy                           0.66       179
#    macro avg       0.66      0.62      0.61       179
# weighted avg       0.66      0.66      0.63       179

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# Replace 'base_estimator' with 'estimator'
model_bagging = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=10, random_state=42)
model_bagging.fit(X_train, y_train)
y_pred_bagging = model_bagging.predict(X_test)
print(classification_report(y_test, y_pred_bagging))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73       105
#            1       0.62      0.46      0.53        74
#
#     accuracy                           0.66       179
#    macro avg       0.65      0.63      0.63       179
# weighted avg       0.65      0.66      0.65       179

# %%
# prompt: make roc curve

from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have already trained a model (e.g., model_lr) and have y_test and y_pred_lr
y_pred_proba = model_lr.predict_proba(X_test)[:, 1]  # Probability of positive class

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
# prompt: Classification Report / Cost (Prediction)

# Assuming you have already trained a model (e.g., model_lr) and have y_test and y_pred_lr
from sklearn.metrics import classification_report, confusion_matrix

# Predict probabilities for the positive class (e.g., survival)
y_pred_proba = model_lr.predict_proba(X_test)[:, 1]

# Generate the classification report
print(classification_report(y_test, y_pred_lr))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_lr)
print("Confusion Matrix:")
print(cm)

# Calculate the cost (prediction) - This will depend on your specific cost function
# For example, if you want to minimize false negatives (missed survivors), you might
# assign a higher cost to a false negative than a false positive.

# You can define a cost function based on the confusion matrix:
cost_fn = 10  # Cost of a false negative (e.g., missing a survivor)
cost_fp = 1   # Cost of a false positive (e.g., incorrectly identifying someone as a survivor)

cost = cm[1, 0] * cost_fn + cm[0, 1] * cost_fp
print("Cost of Prediction:", cost)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79       105
#            1       0.79      0.42      0.55        74
#
#     accuracy                           0.72       179
#    macro avg       0.74      0.67      0.67       179
# weighted avg       0.74      0.72      0.69       179
#
# Confusion Matrix:
# [[97  8]
#  [43 31]]
# Cost of Prediction: 438
